# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaBonillRincon/Analisis_Desaparecidos/blob/main/Analisis_Desaparecidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Desaparecidos de Colombia, registro histórico desde 1901 a marzo de 2024
# ### Análisis y visualización de datos básico - Talento TECH 2024
# **Hecho por Lina Marcela Bonill Rincón**
#
# **Referencia de registros**:https://www.datos.gov.co/Justicia-y-Derecho/Desaparecidos-Colombia-hist-rico-a-os-1930-a-marzo/8hqm-7fdt/about_data
#
# **Objetivos**
#
# - Importar y estudiar los datos de una base de datos libre.
# - Realizar la limpieza de los datos de acuerdo a los tipos de datos
# - Ejecutar comandos que proporcionen información Estadística descriptiva de datos cuantitativos (media, mediana, desviación estándar, máximo y minímo valor)
# - Visualizar mediante gráficos los datos pertinentes de la fuente con el fín de proporcionar información detallada ante posibles interesados.
# - Proporcionar un análisis por cada gráfica en que se de a conocer la magnitud de desapariciones desde 1901 hasta el año 2024 en todos sus campos.
#
# **Herramientas a utilizar**
#
# - Python: Lenguaje de programación que mediante las librerias Pandas y Matplotlib garantizaran la extración y visualización de datos.
# - Jupyter: Entorno gráfico en la que se llevará a cabo la ejecución de codigo con su correspondiente documentación

# %% [markdown]
# ### Importación de datos ###
#
# - Instalar librerias Pandas y Matplotlib para el desarrollo del proyecto con el siguiente comando en la terminal **pip install pandas matplotlib**
# - Al terminar la descarga e instalación se hará la importación de las librerias que son un conjunto de funciones que permitirán llevar a cabo distintos procedimientos.
# - **Pandas**: Libreria que se especializada en la manipulación y análisis de datos
# - **Matplotlib**: Libreria que permite la generación de gráficos 2D

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Se crea la variable **desaparecidos_df**] para recolectar los datos de la base de datos Desaparecidos_Colombia_1930_a_marzo_de_2024 mediante el comando de Pandas cuyo sobrenombre es pd **pd.read_csv**. Cabe resaltar que en los datos se encuentran desde el año 1901 lo que viene siendo un error de la pagina donde se obtuvo los datos.

# %%
url='https://raw.githubusercontent.com/LinaBonillRincon/Analisis_Desaparecidos/main/Desaparecidos_Colombia_1930_a_marzo_de_2024.csv'

# %%
desaparecidos_df=pd.read_csv(url)

# %%
num_registros = desaparecidos_df.shape[0]
print(f"El número de registros en el dataset es: {num_registros}")
# Out:
# El número de registros en el dataset es: 185741

# %% [markdown]
# Se realiza la visualización inicial de los datos, en la cual posee una totalidad de **185741 filas (registros) × 15 columnas (Titulos de los datos)**

# %%
desaparecidos_df
# Out:
#             ID Estado de la desaparición    Clasificación de la desaparición  \
# 0            1              Desaparecido                     Sin Información
# 1            2              Desaparecido                     Sin Información
# 2            3              Desaparecido                     Sin Información
# 3            4             Aparecio Vivo                     Sin Información
# 4            5             Aparecio Vivo                     Sin Información
# ...        ...                       ...                                 ...
# 185736  185996              Desaparecido  Desaparición Presuntamente Forzada
# 185737  185997              Desaparecido                     Sin Información
# 185738  185998              Desaparecido                     Sin Información
# 185739  185999              Desaparecido  Desaparición Presuntamente Forzada
# 185740  186000              Desaparecido                     Sin Información
#
# ...

# %% [markdown]
# ## Información de los datos ##
# Se ejecutarán el comando **type()** para observar el tipo de dato de la variable **desaparecidos_df**
#
# Un **DataFrame** es una estructura de dos dimensiones en que guarda información por filas y columnas es decir que es similar a un **Excel**

# %%
type(desaparecidos_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# A continuación daremos la información resumida acerca de las columnas del DataFrame con el comando **info()**

# %%
# Información de las Columnas - Resumen de datos
desaparecidos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185741 entries, 0 to 185740
# Data columns (total 15 columns):
#  #   Column                                          Non-Null Count   Dtype
# ---  ------                                          --------------   -----
#  0   ID                                              185741 non-null  int64
#  1   Estado de la desaparición                       185741 non-null  object
#  2   Clasificación de la desaparición                185741 non-null  object
#  3   Fecha de la desaparición                        185741 non-null  object
#  4   Edad al momento de la desaparición              185741 non-null  object
#  5   Sexo del desaparecido                           185741 non-null  object
#  6   País de nacimiento del desaparecido             185741 non-null  object
#  7   Ancestro racial del desaparecido                185741 non-null  object
#  8   Estado civil del desaparecido                   185741 non-null  object
# ...

# %% [markdown]
# Se puede observar que cada campo de la tabla esta conformada por:
#
# - *Nombre:* Título que se observa en la tabla
# - *Count:* total de registros
# - *Non-Null:* Significa que el campo no debe estar vacio en ningun registro
#
# Ahora nos enfatizaremos en los tipos de datos de cada campo de la tabla con el comando **dtypes**

# %%
desaparecidos_df.dtypes # Tipos de datos
# Out:
# ID                                                 int64
# Estado de la desaparición                         object
# Clasificación de la desaparición                  object
# Fecha de la desaparición                          object
# Edad al momento de la desaparición                object
# Sexo del desaparecido                             object
# País de nacimiento del desaparecido               object
# Ancestro racial del desaparecido                  object
# Estado civil del desaparecido                     object
# Escolaridad del desaparecido                      object
# Pertenencia grupal del desaparecido               object
# País donde ocurre la desaparición                 object
# Municipio donde ocurre la desaparición DANE       object
# Departamento donde ocurre la desaparición DANE    object
# Contexto                                          object
# dtype: object

# %% [markdown]
# **Nota**
#  **Descripción de las columnas**
#
# - **ID:** Identificación de la desaparición. **Tipo Object - String (Texto)**
# - **Estado de la desaparición:** Corresponde al estado actual de la persona desaparecida. **Tipo Object - String (Texto)**
# - **Clasificación de la desaparición:** Categoria de la persona acorde a la investigación en el Registro Nacional de Desaparecidos **Tipo Object - String (Texto)**
# - **Fecha de la desaparición:** Fecha en que desaparecio la persona **Tipo Object - String (Texto)**
# - **Edad al momento de la desaparición:** Edad de la persona desde su nacimiento hasta el momento de la desaparición **Tipo Object - String (Texto)**
# - **Sexo del desaparecido**: Sexo Masculino o Femenino **Tipo Object - String (Texto)**
# - **País de nacimiento del desaparecido:** País de procedencia de la persona **Tipo Object - String (Texto)**
# - **Ancestro racial del desaparecido:** Descendencia en cada uno de los grupos étnicos **Tipo Object - String (Texto)**
# - **Estado civil del desaparecido:** Vinculo acorde a la ley (matrimonio, unión libre) **Tipo Object - String (Texto)**
# - **Escolaridad del desaparecido:** Grado de escolaridad más alto al cual ha llegado la persona de acuerdo con los niveles del sistema educativo formal. **Tipo Object - String (Texto)**
# - **Pertenencia grupal del desaparecido:** Tipo de característica especial pueden tener más riesgo para ser víctima **Tipo Object - String (Texto)**
# - **País donde ocurre la desaparición:** Estado donde sucedio la desaparición **Tipo Object - String (Texto)**
# - **Municipio donde ocurre la desaparición DANE:** División territorial específica donde ocurrieron los hechos **Tipo Object - String (Texto)**
# - **Departamento donde ocurre la desaparición DANE:** División territorial específica donde ocurrieron los hechos **Tipo Object - String (Texto)**
# - **Contexto:** Se refiere al Contexto registrado en el sistema SIRDEC, en reste caso específico es "Desaparición". **Tipo Object - String (Texto)**

# %% [markdown]
# Para visualizar los primeros 5 registros de la base de datos se utiliza **.head()**

# %%
desaparecidos_df.head()
# Out:
#    ID Estado de la desaparición Clasificación de la desaparición  \
# 0   1              Desaparecido                  Sin Información
# 1   2              Desaparecido                  Sin Información
# 2   3              Desaparecido                  Sin Información
# 3   4             Aparecio Vivo                  Sin Información
# 4   5             Aparecio Vivo                  Sin Información
#
#   Fecha de la desaparición Edad al momento de la desaparición  \
# 0  2006-12-29T00:00:00.000                                 21
# 1  2006-12-26T00:00:00.000                                 24
# 2  2006-12-29T00:00:00.000                                 13
# 3  2006-12-29T00:00:00.000                                 17
# 4  2006-12-31T00:00:00.000                                 71
#
#   Sexo del desaparecido País de nacimiento del desaparecido  \
# 0                Hombre                     Sin información
# 1                Hombre                            Colombia
# ...

# %% [markdown]
# Para visualizar los últimos 5 registros de la base de datos se utiliza **.tail()**

# %%
desaparecidos_df.tail()
# Out:
#             ID Estado de la desaparición    Clasificación de la desaparición  \
# 185736  185996              Desaparecido  Desaparición Presuntamente Forzada
# 185737  185997              Desaparecido                     Sin Información
# 185738  185998              Desaparecido                     Sin Información
# 185739  185999              Desaparecido  Desaparición Presuntamente Forzada
# 185740  186000              Desaparecido                     Sin Información
#
#        Fecha de la desaparición Edad al momento de la desaparición  \
# 185736  2002-11-10T00:00:00.000                                 39
# 185737  2006-08-20T00:00:00.000                                 22
# 185738  1992-04-01T00:00:00.000                                 18
# 185739  2003-01-01T00:00:00.000                                 22
# 185740  2012-11-14T00:00:00.000                                 24
#
#        Sexo del desaparecido País de nacimiento del desaparecido  \
# ...

# %% [markdown]
# La libreria Pandas tiene el **.unique()** el cual nos muestra los elementos únicos que tiene cada tabla, es decir, que nos permite identificar en que clasificación se encuentran los registros ya que en su mayoria de campos son de tipo texto y se observa repetición.

# %%
pd.unique(desaparecidos_df['Estado de la desaparición'])
# Out:
# array(['Desaparecido', 'Aparecio Vivo', 'Aparecio Muerto'], dtype=object)

# %%
pd.unique(desaparecidos_df['Clasificación de la desaparición'])
# Out:
# array(['Sin Información', 'Desaparición Presuntamente Forzada'],
#       dtype=object)

# %%
pd.unique(desaparecidos_df['Sexo del desaparecido'])
# Out:
# array(['Hombre', 'Mujer'], dtype=object)

# %%
pd.unique(desaparecidos_df['Ancestro racial del desaparecido'])
# Out:
# array(['Mestizo', 'Negro', 'Sin Información', 'Blanco', 'Mulato',
#        'Indigena', 'Amarilla'], dtype=object)

# %%
pd.unique(desaparecidos_df['País de nacimiento del desaparecido'])
# Out:
# array(['Sin información', 'Colombia', 'Estados Unidos', 'Venezuela',
#        'Alemania', 'Nicaragua', 'España', 'Perú', 'Panamá', 'Ecuador',
#        'Líbano', 'Brasil', 'Argentina', 'Reino Unido', 'México',
#        'Países Bajos', 'Aruba', 'Italia', 'Canadá', 'Eritrea', 'Uruguay',
#        'Corea del Sur', 'Paraguay', 'Haití', 'Nigeria', 'República Checa',
#        'Bolivia', 'Chile', 'Cuba', 'Paquistán', 'Suecia', 'Guatemala',
#        'Rusia', 'China', 'Rumania', 'República Dominicana', 'Puerto Rico',
#        'Marruecos', 'Francia', 'Austria', 'Estonia', 'Letonia', 'Egipto',
#        'Costa Rica', 'Suiza', 'Curaçao', 'Portugal', 'Irán', 'Jamaica',
#        'Australia', 'República de Sudáfrica', 'Bahrein', 'El Salvador',
#        'Siria', 'Jordania', 'Camerún', 'Turquía', 'Bélgica', 'Vietnam',
#        'Kenia', 'Polonia', 'Bangladesh', 'Filipinas', 'Finlandia',
#        'India', 'Congo', 'Nueva Zelanda', 'Trinidad y Tobago',
# ...

# %% [markdown]
# - **Mulato:** Unión de persona blanca y negra
# - **Amarillo:** Propiamente de Asia
# - **Mestizo:** Unión de persona blanca con un@ indigena.

# %%
pd.unique(desaparecidos_df['Estado civil del desaparecido'])
# Out:
# array(['Soltero (a)', 'Unión Libre', 'Sin Información', 'Casado (a)',
#        'No Aplica', 'Separado(a),Divorciado(a)', 'Viudo (a)'],
#       dtype=object)

# %%
pd.unique(desaparecidos_df['Escolaridad del desaparecido'])
# Out:
# array(['Educación básica secundaria o secundaria baja',
#        'Educación técnica profesional y tecnológica',
#        'Educación básica primaria', 'Educación media o secundaria alta',
#        'Universitario', 'Sin información', 'Sin escolaridad',
#        'Educación inicial y educación preescolar',
#        'Especialización, Maestría o equivalente',
#        'Doctorado o equivalente'], dtype=object)

# %%
pd.unique(desaparecidos_df['Pertenencia grupal del desaparecido'])
# Out:
# array(['Persona adicta a una droga natural o sintética', 'Ninguno',
#        'Otro', 'Persona habitante de la calle', 'Sin información',
#        'Personas en situación de prostitución', 'Maestro/Educador',
#        'Comunidad LGBT', 'Persona en condición de desplazamiento',
#        'Presunto colaborador de grupo ilegal', 'Personas bajo custodia',
#        'Grupos étnicos', 'Personas desmovilizadas o reinsertadas',
#        'Ex convictos (as)',
#        'Campesinos (as) y/o trabajadores (as) del campo',
#        'Personas que ejercen actividades relacionadas con la salud en zonas de conflicto',
#        'Líder', 'Personas que ejercen actividades políticas',
#        'Religiosos',
#        'Personas que ejercen actividades gremiales o sindicales',
#        'Personas que ejercen actividades de periodismo',
#        'Miembros de Organizaciones No Gubernamentales (ONG)',
#        'Funcionarios judiciales',
#        'Herido y/o enfermo bajo protección sanitaria o médica',
# ...

# %%
pd.unique(desaparecidos_df['País donde ocurre la desaparición'])
# Out:
# array(['Colombia', 'Venezuela', 'Ecuador', 'Panamá', 'México', 'Francia',
#        'Estados Unidos', 'Honduras', 'Canadá', 'España', 'Costa Rica',
#        'Bolivia', 'Perú', 'Brasil', 'Chile', 'Italia', 'Uruguay',
#        'Reino Unido', 'Bahamas', 'Sin Información', 'Alemania', 'Aruba',
#        'República Dominicana', 'Surinam', 'Puerto Rico', 'Guatemala',
#        'China', 'Paraguay', 'Polonia', 'Países Bajos', 'Cuba',
#        'Australia', 'Suiza', 'Ucrania', 'Argentina', 'Japón', 'Curaçao',
#        'Turquía'], dtype=object)

# %%
pd.unique(desaparecidos_df['Municipio donde ocurre la desaparición DANE'])
# Out:
# array(['Bogotá D.C.', 'Soacha', 'Melgar', ..., 'Iles', 'Yacuanquer',
#        'Sapuyes'], dtype=object)

# %%
pd.unique(desaparecidos_df['Departamento donde ocurre la desaparición DANE'])
# Out:
# array(['Bogotá D.C.', 'Cundinamarca', 'Tolima', 'Meta', 'Bolívar',
#        'Santander', 'Sin Información', 'Boyacá', 'Norte De Santander',
#        'Antioquia', 'Caquetá', 'Quindio', 'Valle Del Cauca', 'Caldas',
#        'Cesar', 'Atlántico', 'Huila', 'Casanare', 'Risaralda',
#        'La Guajira', 'Guaviare', 'Magdalena',
#        'Desaparecidos en el extranjero', 'Nariño', 'Vichada', 'Arauca',
#        'Putumayo', 'Guainía', 'Córdoba', 'Amazonas', 'Cauca', 'Sucre',
#        'Vaupés', 'Chocó', 'San Andres Y Providencia',
#        'País de la desaparición sin información'], dtype=object)

# %%
pd.unique(desaparecidos_df['Contexto'])
# Out:
# array(['Desaparición'], dtype=object)

# %% [markdown]
# ### Limpieza de los datos ###
#
# En vista de que los titulos de las columnas son bastante largas, se llevará a cabo el cambio en los campos para mejor compresión con ayuda de una variable temporal denominada **desaparecidos_temporal_renombrados**

# %%
desaparecidos_temporal_renombrado={"Estado de la desaparición":"Estado_desaparición",
                                   "Clasificación de la desaparición": "Clasificación",
                                   "Fecha de la desaparición": "Fecha_desaparición",
                                   "Edad al momento de la desaparición": "Edad",
                                   "Sexo del desaparecido": "Sexo",
                                   "País de nacimiento del desaparecido": "País_de_nacimiento",
                                   "Ancestro racial del desaparecido":"Ancestro_racial",
                                   "Estado civil del desaparecido":"Estado_civil",
                                   "Escolaridad del desaparecido":"Escolaridad",
                                   "Pertenencia grupal del desaparecido":"Pertenencia_grupal",
                                   "País donde ocurre la desaparición":"País_desaparicion",
                                   "Municipio donde ocurre la desaparición DANE":"Municipio_desparición",
                                   "Departamento donde ocurre la desaparición DANE":"Departamento_desaparición",
                                   "Contexto":"Contexto"}

# %% [markdown]
# Un análisis de datos exitosa conlleva a realizar cambios en las variables y campos acorde a las necesidades del cliente, por lo que es necesario poner los nuevos titulos de los campos y los datos para almacenarlos en una nueva variable llamada **desaparecidos_df_copia**
#
# Para confirmar la transacción se presenta el comando **desaparecidos_df_copia.head()**

# %%
desaparecidos_df_copia=desaparecidos_df.rename(columns=desaparecidos_temporal_renombrado)
desaparecidos_df_copia.head()
# Out:
#    ID Estado_desaparición    Clasificación       Fecha_desaparición Edad  \
# 0   1        Desaparecido  Sin Información  2006-12-29T00:00:00.000   21
# 1   2        Desaparecido  Sin Información  2006-12-26T00:00:00.000   24
# 2   3        Desaparecido  Sin Información  2006-12-29T00:00:00.000   13
# 3   4       Aparecio Vivo  Sin Información  2006-12-29T00:00:00.000   17
# 4   5       Aparecio Vivo  Sin Información  2006-12-31T00:00:00.000   71
#
#      Sexo País_de_nacimiento Ancestro_racial Estado_civil  \
# 0  Hombre    Sin información         Mestizo  Soltero (a)
# 1  Hombre           Colombia         Mestizo  Soltero (a)
# 2   Mujer           Colombia         Mestizo  Soltero (a)
# 3   Mujer    Sin información         Mestizo  Soltero (a)
# 4  Hombre           Colombia         Mestizo  Unión Libre
#
#                                      Escolaridad  \
# 0  Educación básica secundaria o secundaria baja
# 1  Educación básica secundaria o secundaria baja
# ...

# %% [markdown]
# El primer acto es verificar si los campos no estan vacios con el comando  **.isnull().sum()** el cual rectifica cada registro y lleva una sumatoria

# %%
print(desaparecidos_df_copia.isnull().sum())
# Out:
# ID                           0
# Estado_desaparición          0
# Clasificación                0
# Fecha_desaparición           0
# Edad                         0
# Sexo                         0
# País_de_nacimiento           0
# Ancestro_racial              0
# Estado_civil                 0
# Escolaridad                  0
# Pertenencia_grupal           0
# País_desaparicion            0
# Municipio_desparición        0
# Departamento_desaparición    0
# Contexto                     0
# dtype: int64

# %% [markdown]
# Se puede observar que ningun dato tiene vacios, esto es porque el dato nulo es considerado un tipo texto **"Sin información"**, por lo tanto a continuación se ejecutará el comando el cual ayudará a reemplazar el término por el valor que más se repite en las columnas **Ancestro_racial, Estado civil, País_de_nacimiento, Escolaridad, Pertenencia, País_desaparicion,  y Departamento_desaparición** ya que se pretende analizar la magnitud de personas desaparecidas con las anterior información.

# %%
desaparecidos_df_copia['País_de_nacimiento'] = desaparecidos_df_copia['País_de_nacimiento'].replace("Sin información",desaparecidos_df_copia['País_de_nacimiento'].mode().iloc[0])
desaparecidos_df_copia['Escolaridad'] = desaparecidos_df_copia['Escolaridad'].replace("Sin información",desaparecidos_df_copia['Escolaridad'].mode().iloc[0])
desaparecidos_df_copia['Pertenencia_grupal'] = desaparecidos_df_copia['Pertenencia_grupal'].replace("Sin información",desaparecidos_df_copia['Pertenencia_grupal'].mode().iloc[0])

# %%
desaparecidos_df_copia['Ancestro_racial'] = desaparecidos_df_copia['Ancestro_racial'].replace('Sin Información',desaparecidos_df_copia['Ancestro_racial'].mode().iloc[0])
desaparecidos_df_copia['Estado_civil'] = desaparecidos_df_copia['Estado_civil'].replace("Sin Información",desaparecidos_df_copia['Estado_civil'].mode().iloc[0])
desaparecidos_df_copia['País_desaparicion'] = desaparecidos_df_copia['País_desaparicion'].replace("Sin Información",desaparecidos_df_copia['País_desaparicion'].mode().iloc[0])
desaparecidos_df_copia['Departamento_desaparición'] = desaparecidos_df_copia['Departamento_desaparición'].replace("Sin Información",desaparecidos_df_copia['Departamento_desaparición'].mode().iloc[0])

# %% [markdown]
# Acto siguiente es determinar que variables necesitan un cambio de tipo de dato.
#
# Según descripción de los campos de la tabla (Títulos) se observa que el campo **'Fecha_desaparición'** es de tipo texto, posee formato de hora y guión "2020-12-7T00:00:00" los cuales no son necesarios para el análisis.
#
# Con el  comando **.str.split('T').str[0]** se procede a eliminar registros que cuenten con la "T" hasta el final del texto. Por otro lado, con el comando **.str.replace("-","")** busca en el texto el "-" y lo reemplaza con nada, haciendo que el dato quede de la siguiente manera: **2020127**

# %%
desaparecidos_df_copia['Fecha_desaparición']=desaparecidos_df_copia['Fecha_desaparición'].str.split('T').str[0]
desaparecidos_df_copia['Fecha_desaparición']=desaparecidos_df_copia['Fecha_desaparición'].str.replace("-","")

# %% [markdown]
# Adicionalmente, observando los registro, se detalla que algunos tienen **'Fecha_desaparición'** con **'Sin información'**, estos registros no son relevantes en el análisis por lo que se eliminan haciendo que desaparecidos_df_copia solo tenga los registros que cumplan con la condición de no tener
# **"Sin información"** en el campo de la Fecha.

# %%
desaparecidos_df_copia = desaparecidos_df_copia[desaparecidos_df_copia['Fecha_desaparición'] != "Sin información"]

# %% [markdown]
# También se resalta que en el campo **'Edad'** es de tipo texto y posee números **(1,15,14)** como texto **(Menor de 1 año y Sin información)**
#
# Por lo tanto se realiza nuevamente el procedimiento anterior, haciendo que **desaparecidos_df_copia** no tenga **Menor de 1 año y Sin información** en su campo **'Edad'.**

# %%
desaparecidos_df_copia=desaparecidos_df_copia[desaparecidos_df_copia['Edad']!= "Menor de 1 año" ]
desaparecidos_df_copia=desaparecidos_df_copia[desaparecidos_df_copia['Edad']!= "Sin información" ]

# %% [markdown]
# Siendo datos que a simple vista parecen números y se registran como texto se debe hacer la conversión de un texto a un número con el comando de Pandas **pd.to_numeric()**

# %%
desaparecidos_df_copia['Fecha_desaparición']=pd.to_numeric(desaparecidos_df_copia['Fecha_desaparición'])
desaparecidos_df_copia['Edad']=pd.to_numeric(desaparecidos_df_copia['Edad'])

# %% [markdown]
# El campo **'Fecha_desaparición'** tiene que ser de tipo entero para que el comando de Pandas **pd.to_datetime() con el formato '%Y%m%d' Lo que equivale a año, mes y día** lo convierta a tipo fecha, es decir, **2020127 = 2020-12-7**

# %%
desaparecidos_df_copia['Fecha_desaparición'] = pd.to_datetime(desaparecidos_df_copia['Fecha_desaparición'], format='%Y%m%d')

# %% [markdown]
# Acto siguiente se llevará a cabo la eliminación de la columna **Contexto** ya que no es necesario para el análisis, por tener un solo valor **Desaparición**

# %%
desaparecidos_df_copia = desaparecidos_df_copia.drop(columns=['Contexto'])

# %% [markdown]
# Por último en la Limpieza de datos se utiliza el comando **dtypes** para rectificar los cambios en los campos incluyendo la desaparición de la columna Contexto, como también que la 'Fecha_desaparición y 'Edad' a tipo fecha **datetime64** y **int64** respectivamente.

# %%
desaparecidos_df_copia.dtypes
# Out:
# ID                                    int64
# Estado_desaparición                  object
# Clasificación                        object
# Fecha_desaparición           datetime64[ns]
# Edad                                  int64
# Sexo                                 object
# País_de_nacimiento                   object
# Ancestro_racial                      object
# Estado_civil                         object
# Escolaridad                          object
# Pertenencia_grupal                   object
# País_desaparicion                    object
# Municipio_desparición                object
# Departamento_desaparición            object
# dtype: object

# %% [markdown]
# En caso de verlo en formato tabla solo se debe ejecutar el nombre de la variable que hemos estado trabajando **desaparecidos_df_copia**. Se detalla que la cantidad de registros de se redujo, por lo que ahora trabajaremos con **185249 rows × 14 columns**

# %%
desaparecidos_df_copia
# Out:
#             ID Estado_desaparición                       Clasificación  \
# 0            1        Desaparecido                     Sin Información
# 1            2        Desaparecido                     Sin Información
# 2            3        Desaparecido                     Sin Información
# 3            4       Aparecio Vivo                     Sin Información
# 4            5       Aparecio Vivo                     Sin Información
# ...        ...                 ...                                 ...
# 185736  185996        Desaparecido  Desaparición Presuntamente Forzada
# 185737  185997        Desaparecido                     Sin Información
# 185738  185998        Desaparecido                     Sin Información
# 185739  185999        Desaparecido  Desaparición Presuntamente Forzada
# 185740  186000        Desaparecido                     Sin Información
#
#        Fecha_desaparición  Edad    Sexo País_de_nacimiento Ancestro_racial  \
# ...

# %% [markdown]
# ## Estadística descriptiva ##
#
# En esta sección se tomará el dato númerico de la bases de datos que es 'Edad' y se llevara a cabo un resumen de sus datos con el comando **.describe()**  Esta información incluye el número de muestras, el valor medio, la desviación estándar, el valor mínimo, máximo, la mediana y los valores correspondientes a los percentiles 25%, 50% y 75%.

# %%
desaparecidos_df_copia['Edad'].describe()
# Out:
# count    185249.000000
# mean         29.957571
# std          16.023168
# min           1.000000
# 25%          17.000000
# 50%          26.000000
# 75%          38.000000
# max         110.000000
# Name: Edad, dtype: float64

# %% [markdown]
# Para sacar el mínimo de las edades de las personas desaparecidas se usa el comando **.min()**

# %%
desaparecidos_df_copia['Edad'].min()
# Out:
# 1

# %% [markdown]
# Para sacar el máximo de las edades de las personas desaparecidas se usa el comando **.max()**

# %%
desaparecidos_df_copia['Edad'].max()
# Out:
# 110

# %% [markdown]
# Se utiliza el comando **.mean()** para obtener la media de los datos
#
# Nota: La media es la suma de todos los datos y divida por la cantidad total de datos

# %%
desaparecidos_df_copia['Edad'].mean()
# Out:
# 29.957570621163946

# %% [markdown]
# El comando **.std()** es para conseguir la Desviación estádar,que sirve para calcular la variación en la que puntos de datos individuales difieren de la media

# %%
desaparecidos_df_copia['Edad'].std()
# Out:
# 16.023168109629445

# %% [markdown]
# ## Gráficos y Análisis ##
#
# En la sección  se ejecutará comandos que garantizaran la visualización de gráficos, los cuales se analizaran para mejor comprensión de los interesados

# %% [markdown]
# **Cantidad de desapariciones por año**
#
# A continuación se requiere determinar en que años es elevada la magnitud de desapariciones desde el año 1901 al 2024
#
# Por lo que se realizara un diagrama de linea cuyos puntos representaran la cantidad de desapariciones al transcurrir de los años.
#
# - De la variable **desaparecidos_de_copia** en su sección año, se almacena los años de las fechas de las desapariciones.
# - Se creara una variable temporal **desapariciones_por_año** y se guardará la cantidad de veces que se repite cada año
# -  **plt.figure(figsize=(14, 8))** tamaño de la gráfica
# - **plt.plot(desapariciones_por_año.index, desapariciones_por_año.values, marker='o', linestyle='-', color='red', label='Gente desaparecida')** proporciona los datos de la gráfica que son el año y su cantidad, al mismo tiempo se da componentes de diseño como el marker (los puntos), linestyle (linea de estilo) y la leyenda (label), todo ello con un color rojo.
# - **plt.fill_between(desapariciones_por_año.index, desapariciones_por_año.values, color='slategrey', alpha=0.3)** garantiza un nitido relleno gris claro en el área debajo de la línea.
# - **plt.title('Tendencia de desapariciones através de los años')** Título
# - **plt.xlabel('Años')** Leyenda en el eje x
# - **plt.ylabel('Cantidad de personas')** Leyenda en el eje y
# - **plt.xticks(fontsize=20)**Tamaño de letra en eje x
# - **plt.yticks(fontsize=20)** Tamaño de letra en eje y
# - **plt.legend()** Leyenda
# - **plt.grid(True)** Cuadricula
# - **plt.tight_layout()** Ordenar para que nada sobrepase
# - **plt.show()** Mostrar gráfica

# %%
desaparecidos_df_copia['Año'] = desaparecidos_df_copia['Fecha_desaparición'].dt.year
desapariciones_por_año = desaparecidos_df_copia['Año'].value_counts().sort_index()
plt.figure(figsize=(14, 8)) #Tamaño de gráfica 14 ancho 8 largo
plt.plot(desapariciones_por_año.index, desapariciones_por_año.values, marker='o', linestyle='-', color='red', label='Gente desaparecida')
# marker el punto acorde a la tendencia
plt.fill_between(desapariciones_por_año.index, desapariciones_por_año.values, color='slategrey', alpha=0.3)
#Diseños
plt.title('Tendencia de desapariciones através de los años',fontsize=20) #Titulo
plt.xlabel('Años',fontsize=20) #Label x
plt.ylabel('Cantidad de personas',fontsize=20) #Label Y
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend() #Leyendas
plt.grid(True)
plt.tight_layout() #Orden
plt.show() #Mostrar

# %% [markdown]
# **Análisis Tendencia de desapariciones por años**
#
# - A lo largo de los años  de 1900 hasta aproximadamente 1970 hay una tendencia general de forma plana en la que se evidencia poco indice de desapariciones.
# - A finales de 1970  hasta los años 2005 aproximadamente se presenta un incremento de desapariciones forzosas debido al conflicto armado, narcotrafico y violencia.
# - El periodo con más desapariciones registras es desde al año 2005 hasta el 2022 ya que para ese entonces se pronunciaban los grupos paramilitares y su constante violencia en territorios rurales y urbanos.
# - Se evidencia una caida pronunciada y significativa en el valor de las desapariciones desde el año del 2020 hasta la actualidad debido al inicio de la pandemia COVID19 como también por las negociaciones de Paz por parte del gobierno y lideres de grupos paramilitares lo cual sugiere la disminución de la actividad criminal.

# %% [markdown]
# **Gráfica Paises de nacimiento de los desaparecidos**
#
# Se busca obtener la cantidad de personas que nacieron en Colombia antes de su desaparición, por ello se realiza lo siguiente:
#
# - **plt.figure** Tamaño de gráfico
# - **frecuencia_paises** variable que recolectará el nombre de país como clave con sus correspondiente valor de repeticiones en los registros.
# - **frecuencia_paises.head(16)** La variable tendra en cuenta solamente los primeros 16 ya que son los que tienen más frencuencia en comparación de todos los paises registrados.
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra vértical con color de relleno y línea de contorno.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, rotación, espaciado, tamaño y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks(fontsize=20)**Tamaño de letra en eje x
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
plt.figure(figsize=(10, 10))
frecuencia_paises= desaparecidos_df_copia['País_de_nacimiento'].value_counts()
frecuencia_paises=frecuencia_paises.head(16)
ax = frecuencia_paises.plot(kind='bar', color='cyan', edgecolor='black') #diseño
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points',fontsize=15)

plt.title('Paises de nacimiento de los desaparecidos',fontsize=20)
plt.xlabel('Paises',fontsize=20)
plt.ylabel('Cantidad',fontsize=20)
plt.xticks(fontsize=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis de frecuencia de paises de nacimientos de las victimas**
#
# - Se visualiza que los paises con mayor frencuencia en su mayoria pertenecen a continente Américano y pocos son de Europa.
# - Acorde a la visualización se declara que la mayoria de las victimas nacieron en Colombia.
# - El segundo país con más cantidad es Venezuela, hecho que es por el constante cotacto entre los paises vecinos en cuestión de recursos y habitantes.
# - La gráfica presenta una cola larga (long tail) donde muchos paises tienen una frecuencia baja, esto sugiere que fue muy poco las desapariciones al transcurrir de los años.

# %% [markdown]
# **Gráfica de Cantidad de desapariciones por Pais**
#
# Acorde a la gráfica de **Paises de nacimiento de los desaparecidos** se desea enfatizar cuantas desapariciones sucedieron en Colombia a comparación de los demás paises con registro.
#
# **Descripción del código**
# - **plt.figure** Tamaño de gráfico
# - **frecuencia_paises** variable que recolectará el nombre de cada país como clave con su correspondiente valor de repeticiones en los registros.
# - **frecuencia_paises.head(12)** La variable tendra en cuenta solamente a los paises de más frecuencia debido a que vienen siendo las que tendrán relevancia a la hora de hacer el análisis.
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra vértical con color de relleno  verde y línea de contorno negro.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, rotación, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks(fontsize=20)**Tamaño de letra en eje x
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
plt.figure(figsize=(10, 10))
frecuencia_paises = desaparecidos_df_copia['País_desaparicion'].value_counts()
frecuencia_paises = frecuencia_paises.head(12)
ax = frecuencia_paises.plot(kind='bar', color='forestgreen', edgecolor='black',linewidth=1)

for p in ax.patches:
        ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 15), textcoords='offset points',fontsize=15)
plt.xticks( ha='right')
plt.title('Cantidad de desapariciones por país')
plt.xlabel('Paises')
plt.xticks(fontsize=20)
plt.ylabel('Cantidad')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Gráfico Desapariciones por país**
#
# - A simple vista se identifica que Colombia tiene el mayor indice de desaparecidos registrado en la base de datos, seguida por Venezuela, Ecuador, México, y Perú.
# - Se proyecta  otros paises del mundo debido a que posiblemente las victimas se encontraban en otro territorio al momento de la desaparición
# - A lo que respecta a los otros paises, estos no sobrepasa las 500 personas, lo que propone que las desapariciones en el extrajero eran poco concurrentes.

# %% [markdown]
# **Gráfica de desaparecidos en Colombia**
#
# Teniendo en cuenta la cantidad alarmante de desapariciones en Colombia, es pertinente reconocer la cantidad por cada año desde 1901 al 2024 e identificar que periodo de tiempo es la más signficativa.
#
# **Descripción del codigo**
#
# - **colombia_data** variable en donde se almacena los registros en cuya columna **'País donde ocurre la desaparición'** sea Colombia
# - **colombia_data['Año']** el cual tendrá los años de cada registro ubicado en la columna **'Fecha de la desaparición'**
# - **desapariciones_por_año** variable el cual cuenta la cantidad de veces que se repite el año de desaparición, se almacena como index (año) y valor(cantidad de repetición)
# - **print()** impresión en pantalla de las cantidades y la sumatoria de todas las desapariciones
# - **plt.plot** método en que se presenta los años (index) y sus correspondiente cantidad (valor) con el punto marcado, la linea de estilo y  en color verde.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks(rotate=45,fontsize=20)**Tamaño y rotación de letra en eje x
# - **plt.yticks(fontsize=20)** Tamaño de letra en eje y
# - **plt.grid** Cuadricula
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
colombia_data =desaparecidos_df_copia[desaparecidos_df_copia['País_desaparicion'] == 'Colombia'].copy()
colombia_data['Año'] = colombia_data['Fecha_desaparición'].dt.year
desapariciones_por_año_colombia = colombia_data['Año'].value_counts().sort_index()
print(desapariciones_por_año_colombia)
print(f"total de desapariciones: {desapariciones_por_año_colombia.sum()}")
plt.figure(figsize=(14, 8))
plt.plot(desapariciones_por_año_colombia.index, desapariciones_por_año_colombia.values, marker='o', linestyle='-', color='crimson')
plt.title('Desapariciones en Colombia  lo largo de los años 1901-2024',fontsize=20)
plt.xlabel('Periodo',fontsize=20)
plt.ylabel('Cantidad',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45,fontsize=20)
plt.yticks(fontsize=20)
plt.tight_layout()
plt.show()
# Out:
# Año
# 1901       1
# 1930       1
# 1933       1
# 1937       1
# 1938       1
#         ...
# 2020    5090
# 2021    6722
# 2022    6715
# 2023    6135
# 2024    1237
# Name: count, Length: 83, dtype: int64
# total de desapariciones: 184172

# %% [markdown]
# **Análisis Desapariciones en Colombia**
#
# - Las primeras desapariciones incian a partir de 1901 los cuales fueron escasas y de poca prolongación
# - Se registra incremento leve en las desapariciones después de 1940 ya que en ese entonces se manifestaba un agudo conflicto interno denominado "La vioencia"
# - A partir de 1980 se reconoce un incremento constante en que aumenta el número de desapariciones debido a conflictos internos del país con el narcotráfico.
# - Después del año 2002 hasta el 2006 ocurrio una disminución significativa lo que conllevo a aspirar a tiempos sin Violencia.
# - En base a la información del 2006 al 2018 se vuelve a presenciar un incremento  en que se distingue la cantidad más alta registrada que sobrepasa los 8,000 personas en el año 2011-2012
# - Al llegar el 2020, no se presentaron actos de desaparición debido a la  Pandemia COVID19.
# - El presente año preseta  la disminución más destacada en la que no supera las 2,000 personas.

# %% [markdown]
# **Gráfica Departamento donde ocurre la desaparición según el DANE**
#
# Siguiendo con el análisis de desapariciones en Colombia, se necesita precisar la información de donde se percato más desapariciones en vista de que el país esta constituido por varios departamentos.
#
# **Descripción del código**
#
# - **colombia_data** variable que posee los registros en donde el país donde ocurre la desaparición sea Colombia
# - **frecuencia_departamentos** variable que recolectará el nombre  de cada departamento como index con su correspondiente valor de repeticiones en los registros.
# -  **plt.figure** Tamaño de gráfico
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra horizonal con color de relleno  amarillo y línea de contorno negro.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, rotación, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.grid** cuadricula del gráfico en el eje x
# - **plt.xticks(fontsize=15)**Tamaño de letra en eje x
# - **plt.yticks(fontsize=15)** Tamaño de letra en eje y
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
colombia_data =desaparecidos_df_copia[desaparecidos_df_copia['País_desaparicion'] == 'Colombia'].copy()
frecuencia_departamentos =  colombia_data['Departamento_desaparición'].value_counts()
frecuencia_departamentos=frecuencia_departamentos.head(26)
plt.figure(figsize=(20, 20))
ax=frecuencia_departamentos.plot(kind='barh', color='darkcyan', edgecolor='black',linewidth=2)
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='center', va='center', xytext=(25, 0), textcoords='offset points',fontsize=15)
plt.title('Departamento donde ocurre la desaparición DANE')
plt.xlabel('Cantidad',fontsize=20)
plt.ylabel('Departamentos',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Departamento donde ocurre la desaparición**
#
# - Los Departamentos con más registros son Bogotá, Antioquia, Valle del Cauca, Meta, Cundinamarca y Santander.
# - Bogotá posee una cantidad de 55115 lo cual proporciona mucha diferencia frente a los demás departamentos.
# - Por otro lado, lo que corresponde a San Andrés, Vaupés, Amazonas, Guainía y demás son los que menos registro tiene, por ende las desapariciones no fueron recurrentes al transcurrir de los años.
# - Varios departamentos del país se encuentran en medio del indice mínimo y máximo, es decir, entre 900 a 6000 que en representación gráfica identifica que existe vulnerabilidad en gran parte del territorio Colombiano.

# %% [markdown]
# **Gráficas Desapariciones por Departamentos**
#
# Se escogieron los primeros 6 departamentos con más desapariciones de Colombia, con el fín de detallar su cantidad al transcurrir de los años.
#
# **Descripción del código**
#
# - **top_6_paises** Variable que recolecta los departamentos con más valor de colombia_data
# - **plt.figure** Tamaño de gráfico
#
# Se realiza un ciclo for en donde:
#
# - **departamento_data** variable temporal que adquiere todo los datos cuyo Departamento sea del top 6
# - **departamento_data['Año']** consigue los años de las desapariciones en el departamento
# - **desapariciones_por_departamento_colombia** lleva a cabo la cuenta de las veces que se repite el año con el departamento en cuestion
# - **plt.subplot** Formato de matriz de gráficos, 3 es filas, 2 las columnas y cada gráfico representa a 1 = i departamento
# - **plt.title** Título del gráfico con el departamento correspondiente
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.grid** cuadricula del gráfico
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
top_6_paises = colombia_data['Departamento_desaparición'].value_counts().head(6).index
plt.figure(figsize=(20, 12))
for i, depa in enumerate(top_6_paises, 1):
    departamento_data = colombia_data[colombia_data['Departamento_desaparición'] == depa].copy()
    departamento_data['Año'] = colombia_data['Fecha_desaparición'].dt.year
    desapariciones_por_departamento_colombia = departamento_data['Año'].value_counts().sort_index()
    plt.subplot(3, 2, i)
    plt.plot(desapariciones_por_departamento_colombia.index, desapariciones_por_departamento_colombia.values, marker='o', linestyle='-', label=depa, color="navy")
    plt.title(f'Desapariciones por {depa}',fontsize=20)
    plt.xlabel('Periodo')
    plt.ylabel('Cantidad')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Gráficas por Departamentos con más registros**
#
# **Bogotá**:
#
# - Se evidencia un flujo constante en la cual no manifestaba gran cantidad de casos, no obstante, al llegar el año 2006 a causa de conflictos internos se presencio un incremento lo que produjo los años con más número victimas, hasta la llegada de la Pandemia COVID19 se percato un control que a la actualidad redujo el índice.
#
# **Antioquia**
#
# - Cantidad constante sin notorios cambios hasta un espontanéno incremento en 1980, la cual consiste  una serie de intermitentes sumas y restas de victimas, donde la más alta fue en 2002 con más de 1000 personas y las más baja es el presente año con menos de 200 individuos.
#
# **Valle del Cauca**
#
# - Se reconoce que hubo un flujo constante hasta 1985, lo cual dio inicio a un incremento significativo cuyos picos más altos sobrepasan los 800 personas y el más bajo se encuentra en el presente año.
#
# **Meta**
#
# - Se resalta una tendencia estable  entre 0 a 300 con un aumento drástico hasta alcanzar el pico en el 2002 con más de 600 personas.
#
# **Cundinamarca**
#
# - En Cundinamarca se mantuvo una cantidad controlada con un aumento gradual que cambia a partir del año 2020 en donde hubo un impacto con ascensos y descensos hasta llegar a su pico máximo en el año 2023 con más de 500 personas seguido de una disminución en el año 2024 con menos de 200 victimas.
#
# **Norte de Santander**
#
# - Se resalta una cantidad moderada con un aumento gradual hasta el periodo de 1990-2002 en donde aumenta la cantidad y alcanza sus picos maximos que superan las 300 personas, seguido de esto, es posible que se haya tomado medidas al respecto cuyo resultado fue una disminución y control de casos por debajo de los 300 lo cual sigue intacto en la actualidad.

# %% [markdown]
# **Gráfico de comparación entre departamentos**
#
# A partir de los gráficos anteriores se exige conocer la comparación entre los despartamentos que encabezan la lista con más desapariciones y determinar en que periodo de tiempo se alcanzo su máxima cantidad.
#
# **Descripción del código**
#
# - **plt.figure** Tamaño de gráfico
#
# Se realiza un ciclo for en donde:
#
# - **top_6_paises** Variable declarado antreriormente y su función es recolectar los departamentos con más valor de colombia_data
# - **departamento_data** variable temporal que adquiere todo los datos cuyo Departamento sea por los departamentos que encabezan la lista con más desaparciciones top 6 paises.
# - **departamento_data['Año']** consigue los años de las desapariciones en el departamento
# - **desapariciones_por_departamento_colombia** lleva a cabo la cuenta de las veces que se repite el año con el departamento en cuestión
# - **plt.plo** Crea el gráfico con los siguientes paramentros: El nombre del departamento, la cantidad de repeticiones, los puntos, el estilo de la linea, y el nombre mostrado en pantalla como indicador.
# - **plt.title** Título del gráfico con el departamento correspondiente
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks** Hace que las leyenda del eje x tengan una rotación de 45°
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
plt.figure(figsize=(14, 8))
for pais in top_6_paises:
    departamento_data = colombia_data[colombia_data['Departamento_desaparición'] == pais].copy()
    departamento_data['Año'] = colombia_data['Fecha_desaparición'].dt.year
    desapariciones_por_departamento_colombia = departamento_data['Año'].value_counts().sort_index()
    plt.plot(desapariciones_por_departamento_colombia.index, desapariciones_por_departamento_colombia.values, marker='o', linestyle='-', label=pais)
plt.title('Comparación de Desapariciones por Departamento',fontsize=20)
plt.xlabel('Periodo',fontsize=20)
plt.ylabel('Cantidad',fontsize=20)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Gráfico Comparación entre desapariciones por departamentos**
#
# - En Bogotá se puede decir que a través de los años 1980 hasta mediados del 2024 se aumenta el número de desapariciones
# - En Antioquia se observa que fue el primer departamento que presento desapariciones, y mantuvo una cantidad moderada hasta 1980 en la que aumento la cantidad hasta alcanzar su pico de mas de 900 personas.
# - El que posee menos cantidad al pasar de los años fue el Departamento de Cundinamarca lo cual indica que se ha mantenido moderado con pocos aumentos.
# - Se alcanza a detallar que muchos Departamentos presentan puntos similares o muy cercanos en la cantidad en algunos años.
# - En lo que transcurse el presente año se consta que ha sido el valor más bajo de desapariciones para todos los Departamentos descritos en la gráfica.

# %% [markdown]
# **Gráfica de cantidad de hombres y mujeres desaparecidos**
#
# Se solicita presentar la cantidad de hombres y mujeres que desaparecieron, por consiguiente se ejecutará:
#
# - **plt.figure** Tamaño de gráfico
# - **frecuencia_sexo** variable que obtendrá el sexo (H y M) con sus correspondiente valor de repeticiones en los registros.
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra vértical.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.xticks(fontsize=20)**Tamaño de letra en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
plt.figure(figsize=(10, 10))
frecuencia_sexo = desaparecidos_df_copia['Sexo'].value_counts()
ax = frecuencia_sexo.plot(kind='bar', color='gold', edgecolor='black')

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points',fontsize=20)
plt.title('Frecuencia de Sexo del desaparecid@')
plt.xlabel('Sexo')
plt.xticks(fontsize=20)
plt.ylabel('Cantidad')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Gráfico frecuencia del sexo - Análisis**
#
# - Se contempla que más de la mitad de la población de la base de datos son los Hombres quienes tienen el mayor índice de desapariciones en cambio, el sexo opuesto se encuentra muy por debajo, lo cual sugiere que no ha sido tan recurrente la desaparición de una Mujer.

# %% [markdown]
# **Gráfica edad de personas desaparecidas**
#
# Se quiere determinar la edad en que las victimas tenian al momento de la desaparición.
#
# Respecto al código tiene los siguientes componentes:
#
# - Se crea la variable **moda_edad** la cual recolecta el primer dato más repetido de la columna 'Edad al momento de la desaparición' mediante la método **.mode()[0]**
# - El **print** imprime el resultado en la pantalla
# - **frecuencia_edad** es la variable que tendra las edad y su cantidad de repeticiones
# - **plt.figure** Tamaño de gráfico
# - **ax** Variable temporal que tendra el tipo de gráfico (barra horizontal), el color naranja rojizo y linea negra
# - Se ejecuta un ciclo for en que se ubicará cada leyenda en alto, ancho, posición, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks(fontsize=15)**Tamaño de letra en eje x
# - **plt.yticks(fontsize=15)** Tamaño de letra en eje y
# - **plt.grid** Cuadricula solo en eje x
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
moda_edad = desaparecidos_df_copia['Edad'].mode()[0]
print(f"La moda del año de los desaparecidos es: {moda_edad} años")
frecuencia_edad = desaparecidos_df_copia['Edad'].value_counts()
plt.figure(figsize=(18, 20))
ax=frecuencia_edad.plot(kind='barh', color='orangered', edgecolor='black')
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='center', va='center', xytext=(25, 0), textcoords='offset points', fontsize=15)
plt.title('Edades más repetidos',fontsize=20)
plt.xlabel('Cantidad')
plt.ylabel('Edad')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(axis='x')
plt.tight_layout()
plt.show()
# Out:
# La moda del año de los desaparecidos es: 15 años

# %% [markdown]
# **Análisis de moda en años**
#
# - La gráfica ofrece una perspectiva de arriba hacia abajo en la que representa la edad con menos cantidad hasta la que tiene más.
# -  La frecuencia de los registros por edades varia significativamente abarcando desde los primeros años de vida hasta más del siglo.
# - Se observa que las 5 edades con más frecuencia de desapariciones son menores de edad (15,14,16,17,13) a comparación de los demás registros.
# - A partir de los 18 años hasta los 30 se evidencia cantidades de edades muy cercanas, es decir, que no tienen mucha diferencia entre si
# - Despúes de los 30 años se determina una caida significativa en el número de victimas.
# - Las edades con menos cantidad son aquellos que sobrepasaron el siglo.

# %% [markdown]
# **Gráfico edad entre hombres y mujeres**
#
# A partir de los datos de edad y sexo, se requiere determinar en que rango de edades se encuentran más vulnerables las victimas Hombres y Mujeres.
#
# **Descripción del código**
#
# -**groups** variable temporal que adquiere los sexos de los desaparecidos y lo agrupa.
# - **n_groups** hace el conteo de cuantos grupos de sexo hay (2)
# - **fig, axes** las gráficas por numero de grupos 2 filas y 1 columna con sus repectivo tamaño.
# - **if n_groups == 1:** se asegura que a pesar de ser un solo grupo se agrega a un array
# - El ciclo for garantiza la creación de los gráficos acorde al nombre del grupo y espacios, adicionalmente, proprciona la creación y visualización de los Histograma cuyos parámetros son el campo **'Edad al momento de la desaparición'** agrupado con **groups 'Sexo del desaparecido'**. El **bins** permite la creación de intervalos y se asigna estilo como color y borde.
# - También en el ciclo da el titulo de gráfico **ax.set_title**, y de los ejes x y y **ax.set_xlabel - ax.set_ylabel**
# - **plt.tight_layout()** hace que los componentes de los gráficos no se sobrepongan.
# - **plt.show** muesta la gráfica.

# %%
groups = desaparecidos_df_copia.groupby('Sexo')

n_groups = len(groups)

# Crear una figura y ejes
fig, axes = plt.subplots(n_groups, 1, figsize=(8, 6))

# Asegurar que axes sea un array, incluso si hay un solo grupo
if n_groups == 1:
    axes = [axes]

# Dibujar un histograma para cada grupo
for (name, group), ax in zip(groups, axes):
    ax.hist(group['Edad'], bins=15, edgecolor='red', color='yellow')
    ax.set_title(f'Sexo del desaparecido: {name}')
    ax.set_xlabel('Edad al momento de la desaparición')
    ax.set_ylabel('Frecuencia')

# Ajustar el layout
plt.tight_layout()

plt.show()

# %% [markdown]
# **Análisis gráfica Comparación de edades entre Hombres y Mujeres**
#
# - Se observa que el rango de edad en la que estan más vulnerables de ambos sexos es entre los 15 a 20 años.
# - Los Hombres a diferencia de las mujeres tiene más indice de victimas de todas las edades.
# - Se detalla que después de los 25 años a las mujeres se presenta una disminución  de cola larga (long tail) que proclama que las desapariciones en edades avanzadas es poco recurrente.
# - Las edades más avanzadas para ambos sexos es cercana o sobrepasada de los 100 años.
# - Después de los 40 años en los hombres se identifica una disminución que declara que las desapariciones son pocas.

# %% [markdown]
# **Gráfica frecuencia de desapariciones de jovenes de 15 años en los departamentos de Colombia**
#
# Al observar gráficas anteriores se detalla que los jóvenes de 15 años son las principales victimas de desapariciones a nivel nacional, por lo que se desea determinar que departamento es donde más ocurren.
#
# **Descripción del código**
#
# - **colombia_data_15** variable temporal que tendran los registros cuya edad es de 15 años.
# - **frecuencia_departamentos_15** variable temporal que tendra el conteo de los departamentos de **colombia_data_15**
# - **frecuencia_departamentos_15.head(10)** almacenara los primeros 10 departamentos que poseen mayor frecuencia.
# - **plt.figure** tamaño de la gráfica
# - **x_positions** rango en la cantidad de registros de **frecuencia_departamento_15**
# - **plt.scatter** permite la creación de las burbujas con estilos, ubicación y valores.
# - **Ciclo for** implementa la ubicación y estilo de las anotaciones, es decir, los valores resultantes.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.xticks** proporciona estilo a las leyenda del eje x
# - **plt.ylabel** Leyenda en eje y que no las visualiza
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
colombia_data_15 =desaparecidos_df_copia[desaparecidos_df_copia['Edad'] == 15].copy()
frecuencia_departamentos_15 = colombia_data_15 ['Departamento_desaparición'].value_counts()

frecuencia_departamentos_15=frecuencia_departamentos_15.head(10)
plt.figure(figsize=(30, 8))
x_positions = range(len(frecuencia_departamentos_15))
# Crear el gráfico de burbujas
plt.scatter(x_positions, [1] * len(frecuencia_departamentos_15), s=frecuencia_departamentos_15.values*8, alpha=0.6, edgecolors="w", color='blue')

# Agregar anotaciones para cada burbuja
for i, value in enumerate(frecuencia_departamentos_15.values):
    plt.annotate(f'{value}', (i, 1), ha='center', va='center', fontsize=22, color='white')

plt.title('Cantidad de personas de 15 años desaparecidas por departamento con más frecuencia en Colombia', fontsize=30)
plt.xlabel('Departamentos', fontsize=20)
plt.xticks(x_positions, frecuencia_departamentos_15.index, rotation=45, fontsize=25)
plt.yticks([])  # Ocultar el eje yd
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis frente a la cantidad de jovenes de 15 años desaparecidos por departamento**
#
# - En general se visualiza que los departamentos de Colombia se encuentran con cifras inquietantes de desapariciones de jóvenes de 15 años.
# - Bogotá D.C es el departamento que encabeza la frecuencia con 4738 Jóvenes de 15 años victimas de desapariciones.
# - Antiquia y Valle del Cauca también son despartamentos con cifras alarmantes que sobrepasan los 500 jóvenes.
# - A partir de Cundinamarca hasta el Huila, posee valores que no sobrepasan las 500 personas, lo que sugiere que hay una diferencia y las desapariciones no fueron tan impactante para los jovenes de 15 años a comparación de los 3 primeros.

# %% [markdown]
# **Gráfico Ancentro racial de los desaparecidos**
#
# El subtítulo indica que se necesita conocer el ancestro racial de los desaparecidos, es decir, el color de la piel; para ello se elabora el siguiente código:
#
# - **plt.pie** Es el tipo de gráfica circular, tiene en cuenta la cantidad en que se repite el tipo de clasificación **value_counts()**, **labels** son las leyendas, tanto el nombre de la clasificación como su porcentaje como dato flotante con dos números después de la coma. Por último esta la instrucción  **wedgeprops=dict(width=0.5)** que garantiza la apertura del circulo para volverlo estilo dona.
# - **desaparecidos_sin_amarilla** variable temporal que no tiene en cuenta los registros cuyo Ancentro Racial es Amarilla, debido a no aporta para el presente análisis ya que equivale a menos del 0,05 % es decir, aproximadamente 84 registros.
# - **plt.title('Clasificación de la desaparición')** Titulo de la gráfica
# - **plt.show()** Mostrar la gráfica en pantalla

# %%
plt.figure(figsize=(10, 10))
desaparecidos_sin_amarilla=desaparecidos_df_copia[desaparecidos_df_copia['Ancestro_racial']!= "Amarilla" ]
plt.pie(desaparecidos_sin_amarilla['Ancestro_racial'].value_counts(), labels=pd.unique(desaparecidos_sin_amarilla['Ancestro_racial']), autopct="%0.2f %%", wedgeprops=dict(width=0.5))
plt.title('Ancestro racial de los desaparecido')
plt.show()

# %% [markdown]
# **Análisis Ancentro Racial**
#
# - El mayor porcentaje se presenta en victimas de Ancentro racial Mestiza, lo cual representa a más de la mitad de la población escogida.
# - En segundo puesto corresponde Ancestro racial negro, que respecto a Colombia cuenta con gran número de habitantes.
# - A lo que respecta a las victimas Mulatos, Blancos, Indigenas y Amarillas no se presenta un indice significativo alarmante lo que se considera que no se presento frecuentes desapariciones a través de los años.

# %% [markdown]
# **Gráfico Estado civil de los desaparecidos**
#
# Se pretende analizar la cantidad de victimas que pertenezcan a un cierto estado civil según la ley Colombiana, para ello se codificará los siguientes comandos:
#
# - **plt.figure** Tamaño de gráfico
# - **frecuencia_estado** variable que recolectará el estado civil como clave con su correspondiente valor de repeticiones en los registros.
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra vértical con color de relleno y línea de contorno.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, rotación, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.xticks(fontsize=15)**Tamaño de letra en eje x
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
plt.figure(figsize=(10, 10))

frecuencia_estado = desaparecidos_df_copia['Estado_civil'].value_counts()

ax = frecuencia_estado.plot(kind='bar', color='olive', edgecolor='black')
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=20)

plt.title('Estado civil de los desaparecid@',fontsize=20)
plt.xlabel('Estados Civiles')
plt.ylabel('Cantidad')
plt.xticks(fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Estado civil de los desaparecidos**
#
# - La gráfica presenta una cola larga (long tail) donde se evidencia desde el dato con más cantidad a la de menos cantidad.
# - Acorde a la visualización se puede presenciar que gran cantidad de victimas eran solteros ya que según análisis anteriores la mayoria de personas eran menores de edad que no tenian contemplado conseguir pareja a tan temprana edad.
# - Se expone que existen un campo **No aplica**, que sugiere que personas allegadas a la victima no contaban la información o la consideraron fuera de lugar para la investigación.
# - El dato con menos cantidad es **Viudo (a)** con un total de 1,692 lo que es equivalente a 0,9% -> 1% de la población estudiada.

# %% [markdown]
# **Gráfico de Escolaridad de los desaparecidos**
#
# Se representará la cantidad de victimas con escolaridad desde basica primaria hasta Doctorados
#
# - **frecuencia_escolaridad** variable que recolectará el titulo de cada nivel de escolaridad como clave con su correspondiente valor de repeticiones en los registros.
# - **ax - fig** variable que contiene las instrucciones de diseño de una gráfica de tamaño de figura
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, espaciado y tipo de letra con color de relleno  azul claro y circulo de contorno negro.
# - **ax.set_xticks** y **ax.set_xticklabels** garantizan la ubicación de las leyendas en el eje x
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
frecuencia_escolaridad = desaparecidos_df_copia['Escolaridad'].value_counts()
fig, ax = plt.subplots(figsize=(10, 10))


for i, (label, value) in enumerate(frecuencia_escolaridad.items()):
    ax.scatter([i] * value, range(value), color='black', s=30, edgecolor='skyblue')
    ax.annotate(f'{value}', (i, value - 1), ha='center', va='bottom', xytext=(0, 0), textcoords='offset points',fontsize=15)

ax.set_xticks(range(len(frecuencia_escolaridad)))
ax.set_xticklabels(frecuencia_escolaridad.index, rotation=45, ha='right')
plt.title('Escolaridad de los desaparecidos',fontsize=20)
plt.xlabel('Escolaridad')
plt.ylabel('Cantidad')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Gráfico Escolaridad de los desaparecidos**
#
# - Las victimas desaparecidas en su mayoria contaba con Educación primaria y secundaria, lo que corrobora con las edades demostradas anteriormente ya que siendo menores de edad se encontraban en proceso de aprendizaje.
# - Por otro lado, se visualiza poca participación de las victimas en procesos de educación superior debido a escases oportunidades y recursos económicos

# %% [markdown]
# **Gráfico Pertenencia grupal de los desaparecidos**
#
# Se considera pertienente detallar la cantidad de personas que antes de su desaparición tenia algún tipo de antecedente, o ejercia una profesión legal.
#
# **Descripción del código**
# - **plt.figure** Tamaño de gráfico
# - **frecuencia_estado** variable que recolectará el titulo de cada nivel de escolaridad como clave con su correspondiente valor de repeticiones en los registros.
# - **ax** variable que contiene las instrucciones de diseño de una gráfica en barra vértical con color de relleno  azul oscuro y línea de contorno negro.
# - **Ciclo for** en que se ubicará cada anotación en alto, ancho, posición, rotación, espaciado y tipo de letra.
# - **plt.title** Título del gráfico
# - **plt.xlabel** Leyenda en eje x
# - **plt.ylabel** Leyenda en eje y
# - **plt.yticks(fontsize=20)** Tamaño de letra en eje y
# - **plt.tight_layout()** Organización sin sobreponerse
# - **plt.show()** Mostrar la gráfica

# %%
frecuencia_pertenencia = desaparecidos_df_copia['Pertenencia_grupal'].value_counts()
plt.figure(figsize=(30, 20))
ax=frecuencia_pertenencia .plot(kind='barh', color='firebrick', edgecolor='black')
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='center', va='center', xytext=(40, 0), textcoords='offset points',fontsize=20)
plt.title('Pertenencia grupal de los desaparecidos',fontsize=20)
plt.xlabel('Cantidad')
plt.ylabel('Tipo de pertenencia grupal',fontsize=20)
plt.yticks(fontsize=20)
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis Pertenencia grupal de los desaparecidos**
#
# - La bases de datos ofrece una gran variedad de grupos a los que posiblemente pertenecian las victimas antes de la desaparición, cuya categoria es asignada de acuedo a alguna condición fisica, condición mental, profesión, creencia, actos delictivos, entre otros.
# - Se da a conocer que los datos **Ninguno** Son los que constituye a la mayor cantidad de personas (142,199), debido a que no pertenecian a ningun grupo, no cometerieron actos delictivos y no ejercian alguna profesión.
# - Se contempla a los habitantes de zonas rurales como son trabajadores y desplazados a causa de las dictaduras paramilitares.
# - Existe poca cantidad pero no menos significativa frente a individuos consumidores de drogas y criminales, los que posiblemente mantenian estrecha relación con grupos al margen de la ley.
# - Frente a profesiones como Maestros, politicos, lideres, periodistas, entre otros, se observa una baja cantidad lo que indica que las desapariciones no fueron regulares.

# %% [markdown]
# **Gráfico Estados de la desaparición**
#
# Se desea observar la cantidad de los Estados de la desaparición de los registros, ya que algunos según la tabla algunos aparecieron vivos, otros muertos o sin información
#
# Para ello se sigue los siguientes pasos:
#
# - Se crea una variable temporal **frecuencua_estado** que tendra el tipo de estado y su correspondiente número de veces que se repite
# - **plt** pertenece a la libreria Matplotlib, **plt.figure(figsize=(18,20))** corresponde al tamaño de la gráfica
# - **ax** es la variable que contiene la **frecuencia_estado.plt(kind='barh', color='cyan', edgecolor='black')** en la cual indica que la gráfica va a ser de barras horizontales, va a tener color azul y lineas de color negro.
# - Se ejecuta un ciclo for en la que ubica los datos de **ax** en la gráfica con tamaño, color, tipo de letra, y posición.
# - **plt.title** El titulo de la gráfica.
# - **plt.xlabel** Titulo del eje x
# - **plt.ylabel** Titulo del eje y
# - **plt.grid(axis='x')** Marca las lineas del espacio en el eje x
# - **plt.tight_layout()** Ajuste
# - **plt.show()** Mostrar la gráfica

# %%
frecuencia_estado = desaparecidos_df_copia['Estado_desaparición'].value_counts()
plt.figure(figsize=(15, 10))
ax=frecuencia_estado.plot(kind='barh', color='lightskyblue', edgecolor='black')
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2),
                ha='center', va='center', xytext=(-30, 0), textcoords='offset points', fontsize=15)
plt.title('Estado de la desapariciones',fontsize=15)
plt.xlabel('Cantidad')
plt.ylabel('Estados')
plt.yticks(fontsize=15)
plt.grid(axis='x')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Análisis de la gráfica "Estado de las desapariciones"**
#
# Se puede evidencia la comparación entre los tipos de Estado de las desapariciones, y se puede deducir lo siguiente:
# -  **Estado Desaparecido** tiene 120,262 personas, los cuales aún no se ha confirmado sospecha alguna de su paradero.
# -  **Estado Aparecio Muerto** tiene 54,958, está en el segundo lugar en donde se encontro el cuerpo de la persona sin vida.
# -  **Estado Aparecio vivo** tiene 10029 casos, siendo este el último lugar en que la persona se encuentra viva.

# %% [markdown]
# **Gráfica Clasificación de la desaparición**
#
# La siguiente gráfica corresponde a diagrama Circular - Pie del campo **'Clasificación de la desaparición'**
#
# - **plt.pie(desaparecidos_df_copia['Clasificación de la desaparición'].value_counts(), labels=pd.unique(desaparecidos_df_copia['Clasificación de la desaparición']), autopct="%0.1f %%")** Tiene en cuenta la cantidad en que se repite el tipo de clasificación **value_counts()**, labels son las leyendas, tanto el nombre de la clasificación como su porcentaje como dato flotante.
# - **plt.title('Clasificación de la desaparición')** Titulo de la gráfica
# - **plt.show()** Mostrar la gráfica

# %%
plt.pie(desaparecidos_df_copia['Clasificación'].value_counts(), labels=pd.unique(desaparecidos_df_copia['Clasificación']), autopct="%0.1f %%")
plt.title('Clasificación de la desaparición',fontsize=15)
plt.show()

# %% [markdown]
# **Análisis - Clasificación de la desaparición**
#
# - Se observa que el **69.8%** esta **sin información**, lo cual sugiere que las personas cercanas a la victima no cuentan con la idea del motivo de la desaparición.
# - La **Desaparición Presuntamente forzada** equivale al **30.2%** que puede ser debido a dictaduras militares o conflictos con terceros en la que la victima esta en peligro de sufrir otras violaciones de derechos humanos.

# %% [markdown]
# ### Conclusiones  ###
#
# Acorde a los objetivos planteados al inicio de este análisis se concluye lo siguiente
#
# - Se efectuo satisfactoria la importación y estudio de los datos mediante la libreria Pandas ya que se observo cada componente en los registros con su correspondiente aporte a la información.
# - A partir al estudio de la fuente se identifico que elementos eran o no relevantes para el análisis, al mismo tiempo, los que necesitaban una transformación en el tipo de dato para llevar a cabo un estudio más detallado sin nulos, asegurando la mayor calidad en los datos.
# - Gracias a los comandos estudiados en clase y de manera autonoma se brindo claramente los datos estadísticos descriptivos en el campo edad, el cual se determino tanto el mínimo, el máximo y la edad promedio de las personas victimas de desapariciones.
# - Mediante la libreria Matplotlib se garantizo una clara visualización de los datos en gráficas, siendo aquello que facilita la comprensión de los interesados a la hora de reconocer la magnitud de desaparecidos.
# - Por último, cabe resaltar que al iniciar una gráfica se ofrecio una detallada aclaración acerca del objetivo de la figura junto la función que comple cada segmento de código, y al finalizar se proporciona un análisis de lo que se puede observar como es el comportamiento de las despariciones en sus distintos campos.
#
# Respecto a los datos previamente analizados y visualizados se puede concluir lo siguiente:
#
# - El agrupamiento y conteo de desapariciones por departamento muestra una distribución desigual, con algunos departamentos teniendo una mayor cantidad  que otros. Esto podría reflejar diferencias en la demanda de la densidad de población, o políticas regionales de seguridad. El análisis de los datos muestra que algunos departamentos tienen una mayor concentración de desapariciones.
# Estos departamentos podrían ser el foco de futuros estudios para entender las razones detrás de esta concentración.
#
# - Frente al conteo de las personas a partir de sus datos que muestra una distribución alarmante el cual pone en evidencia a los jóvenes como principales victimas de vulnerabilidad en desapariciones.
#
# - Acerca de los informes de estado y clasificación se determina que muchas investigaciones no contemplan información actualizada lo cual alarga los casos.

# %% [markdown]
# ### Recomendaciones ###
#
# En vista de la magnitud de desaparecidos presentado en las gráficas anteriores se recomienda lo siguiente:
#
# - Retomar investigaciones para incrementar los indices de victimas encontradas.
# - Monitorear de manera constante para verificar la actualización de los datos de las victimas.
# - Incrementar la seguridad a nivel nacional debido a que se presenta grandes indice de desapariciones, sobre todo el los departamentos del Cundinamarca, Antioquia, Meta, Valle del Cauca, y Norte de Santader.
# - Implementar un sistema de protección a los menores de 25 años debido a que son población más vulnerable estadísticamente.
# - Llevar a cabo una investigación más explicita acerca de la clasificación de victima, ya que en su mayoria se presenta sin información, lo cual invalida en orden de prioridad.
# - Proponer estrategia de contacto inmediato en caso de desapariciones que funcione a nivel nacional e internacional.

# %% [markdown]
# ### Exportación de datos ###
#
# Se llevará a cabo el último pasoes la exportación de los datos ya limpios para posteriores análisis y visualizaciones

# %%
from google.colab import drive
drive.mount('/content/drive')
desaparecidos_df_copia.to_csv('/content/drive/My Drive/excel_looker/Desaparecidos_1901_2024_final.csv',index=False)
# Out:
# Mounted at /content/drive
